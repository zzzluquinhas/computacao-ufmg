# %%
print("CADASTRA 1")
for i in range(1,40001):
  print("ENTREGA 1 0", i, "ª mensagem para 1 FIM")
# Out:
# CADASTRA 1
# ENTREGA 1 0 1 ª mensagem para 1 FIM
# ENTREGA 1 0 2 ª mensagem para 1 FIM
# ENTREGA 1 0 3 ª mensagem para 1 FIM
# ENTREGA 1 0 4 ª mensagem para 1 FIM
# ENTREGA 1 0 5 ª mensagem para 1 FIM
# ENTREGA 1 0 6 ª mensagem para 1 FIM
# ENTREGA 1 0 7 ª mensagem para 1 FIM
# ENTREGA 1 0 8 ª mensagem para 1 FIM
# ENTREGA 1 0 9 ª mensagem para 1 FIM
# ENTREGA 1 0 10 ª mensagem para 1 FIM
# ENTREGA 1 0 11 ª mensagem para 1 FIM
# ENTREGA 1 0 12 ª mensagem para 1 FIM
# ENTREGA 1 0 13 ª mensagem para 1 FIM
# ENTREGA 1 0 14 ª mensagem para 1 FIM
# ENTREGA 1 0 15 ª mensagem para 1 FIM
# ENTREGA 1 0 16 ª mensagem para 1 FIM
# ENTREGA 1 0 17 ª mensagem para 1 FIM
# ENTREGA 1 0 18 ª mensagem para 1 FIM
# ENTREGA 1 0 19 ª mensagem para 1 FIM
# ENTREGA 1 0 20 ª mensagem para 1 FIM
# ENTREGA 1 0 21 ª mensagem para 1 FIM
# ENTREGA 1 0 22 ª mensagem para 1 FIM
# ENTREGA 1 0 23 ª mensagem para 1 FIM
# ENTREGA 1 0 24 ª mensagem para 1 FIM
# ENTREGA 1 0 25 ª mensagem para 1 FIM
# ...
